# %% [markdown]
# # Exploratory analysis for CIS
# Use this notebook to visualize activation perturbations, logit trajectories, and geometric costs after running pilots.

# %%
# Placeholder for loading results and plotting
# Fill in with analysis code once experiments are available.
